# %%
x<-3

# %%
print(x)
# Out:
# [1] 3

# %%
hist(c(0,1,3,1,3,5,5,6,9,1,2,7), xlab="My histogram")
# Out:
# Plot with title “Histogram of c(0, 1, 3, 1, 3, 5, 5, 6, 9, 1, 2, 7)”

# %%
installed.packages()
# Out:
#             Package
# BH          BH
# IRdisplay   IRdisplay
# IRkernel    IRkernel
# KernSmooth  KernSmooth
# MASS        MASS
# Matrix      Matrix
# R6          R6
# Rcpp        Rcpp
# VGAM        VGAM
# assertthat  assertthat
# backports   backports
# base        base
# base64enc   base64enc
# boot        boot
# cellranger  cellranger
# class       class
# cli         cli
# cluster     cluster
# codetools   codetools
# compiler    compiler
# crayon      crayon
# datasets    datasets
# digest      digest
# dplyr       dplyr
# ellipsis    ellipsis
# evaluate    evaluate
# fansi       fansi
# foreign     foreign
# glue        glue
# grDevices   grDevices
# ⋮           ⋮
# pillar      pillar
# pkgconfig   pkgconfig
# plogr       plogr
# plyr        plyr
# poweRlaw    poweRlaw
# prettyunits prettyunits
# progress    progress
# purrr       purrr
# rJava       rJava
# readxl      readxl
# rematch     rematch
# repr        repr
# rlang       rlang
# rpart       rpart
# ...
